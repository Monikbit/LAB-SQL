# %% [markdown]
# # <font color='darkorange'>  Lab | SQL Queries 9 </font>
# - Create a Python connection with SQL database and retrieve the results of the last two queries (also mentioned below) as dataframes:

# %% [markdown]
# - Te dejo aqui el link de mi repositorio para la parte de SQL
# https://github.com/Monikbit/Lab-SQL-DataAnalysis/blob/main/Laboratorio6.sql

# %%
from sqlalchemy import create_engine 
import pandas as pd
import numpy as np
import getpass
import pymysql

# %%
password=getpass.getpass()

# %% [markdown]
# - Establecemos conexion con mysql

# %%
connection_string='mysql+pymysql://root:'+password+'@127.0.0.1/sakila'
engine=create_engine(connection_string)

# %% [markdown]
# - Check the number of rentals for each customer for May

# %%
query="SELECT c.customer_id,  c.first_name as nombre, c.last_name as apellido,  COUNT(r.rental_may_id) as num_rentas \
FROM customer as c \
INNER JOIN rental_may as r ON c.customer_id = r.customer_id \
GROUP BY c.customer_id \
ORDER BY num_rentas DESC" 
data1=pd.read_sql_query(query,engine)
data1.head()
# Out:
#    customer_id     nombre apellido  num_rentas
# 0          197        SUE   PETERS           8
# 1          506     LESLIE   SEWARD           7
# 2          109       EDNA     WEST           7
# 3          269  CASSANDRA  WALTERS           6
# 4          239     MINNIE   ROMERO           6

# %% [markdown]
# - Check the number of rentals for each customer for June

# %%
query="SELECT c.customer_id,  c.first_name as nombre, c.last_name as apellido,  COUNT(r.rental_june_id) as num_rentas \
FROM customer as c \
INNER JOIN rental_june as r ON c.customer_id = r.customer_id \
GROUP BY c.customer_id \
ORDER BY num_rentas DESC"  
data2=pd.read_sql_query(query,engine)
data2.head()
# Out:
#    customer_id  nombre  apellido  num_rentas
# 0           31  BRENDA    WRIGHT          11
# 1          454    ALEX   GRESHAM          10
# 2          329   FRANK  WAGGONER           9
# 3          295   DAISY     BATES           9
# 4          561     IAN     STILL           9

# %% [markdown]
# - Write a function that checks if customer borrowed more or less films in the month of June as compared to May.

# %%
data3=data1.merge(data2, left_on='customer_id', right_on='customer_id') 
data3
# Out:
#      customer_id   nombre_x apellido_x  num_rentas_x   nombre_y apellido_y  \
# 0            197        SUE     PETERS             8        SUE     PETERS
# 1            506     LESLIE     SEWARD             7     LESLIE     SEWARD
# 2            109       EDNA       WEST             7       EDNA       WEST
# 3            269  CASSANDRA    WALTERS             6  CASSANDRA    WALTERS
# 4            239     MINNIE     ROMERO             6     MINNIE     ROMERO
# ..           ...        ...        ...           ...        ...        ...
# 507          234    CLAUDIA     FULLER             1    CLAUDIA     FULLER
# 508          431       JOEL  FRANCISCO             1       JOEL  FRANCISCO
# 509          351       JACK      FOUST             1       JACK      FOUST
# 510           10    DOROTHY     TAYLOR             1    DOROTHY     TAYLOR
# 511          136      ANITA    MORALES             1      ANITA    MORALES
#
#      num_rentas_y
# 0               8
# 1               5
# ...

# %%
type(data3)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#  # <font color='darkcyan'># Forma 1 </font>

# %%
data3=data1.merge(data2, left_on='customer_id', right_on='customer_id') 
# Para una sola consulta
if data3['num_rentas_x'].iloc[1]< data3['num_rentas_y'].iloc[1]:
            print(data3['nombre_x'][1], data3['apellido_x'][1],'rento menos peliculas en Junio que en Mayo')
else:
            print(data3['nombre_x'][1], data3['apellido_x'][1],'rento la misma cantidad de peliculas en Junio y en Mayo')
# Out:
# LESLIE SEWARD rento la misma cantidad de peliculas en Junio y en Mayo

# %%
def check_rents(x):
   
    for i in range(0,512):  
     if x['num_rentas_x'].iloc[i] < x['num_rentas_y'].iloc[i]:
        print(x['nombre_x'][i], x['apellido_x'][i],'rento menos peliculas en Junio que en Mayo')
     elif x['num_rentas_x'].iloc[i] > x['num_rentas_y'].iloc[i]:
        print(x['nombre_x'][i], x['apellido_x'][i],'rento mas peliculas en Mayo que en Junio')
     else:
        print(x['nombre_x'][i], x['apellido_x'][i],'rento la misma cantidad de peliculas en Junio y en Mayo')

# %%
check_rents(data3)
# Out:
# SUE PETERS rento la misma cantidad de peliculas en Junio y en Mayo
# LESLIE SEWARD rento mas peliculas en Mayo que en Junio
# EDNA WEST rento mas peliculas en Mayo que en Junio
# CASSANDRA WALTERS rento mas peliculas en Mayo que en Junio
# MINNIE ROMERO rento mas peliculas en Mayo que en Junio
# RUTH MARTINEZ rento mas peliculas en Mayo que en Junio
# BILLY POULIN rento menos peliculas en Junio que en Mayo
# GERTRUDE CASTILLO rento mas peliculas en Mayo que en Junio
# COURTNEY DAY rento mas peliculas en Mayo que en Junio
# HEATHER MORRIS rento mas peliculas en Mayo que en Junio
# NAOMI JENNINGS rento mas peliculas en Mayo que en Junio
# VICKIE BREWER rento mas peliculas en Mayo que en Junio
# ENRIQUE FORSYTHE rento mas peliculas en Mayo que en Junio
# GERALDINE PERKINS rento mas peliculas en Mayo que en Junio
# DELORES HANSEN rento mas peliculas en Mayo que en Junio
# ISAAC OGLESBY rento mas peliculas en Mayo que en Junio
# MARIE TURNER rento mas peliculas en Mayo que en Junio
# ...

# %% [markdown]
#  # <font color='darkcyan'># Forma 2 </font>

# %%
data3=data1.merge(data2, left_on='customer_id', right_on='customer_id') 
def check_rents2(df):
    df['diff'] = df['num_rentas_y'] - df['num_rentas_x']
    return df
# No logre meter en esta el texto

# %%
check_rents2(data3)
# Out:
#      customer_id   nombre_x apellido_x  num_rentas_x   nombre_y apellido_y  \
# 0            197        SUE     PETERS             8        SUE     PETERS
# 1            506     LESLIE     SEWARD             7     LESLIE     SEWARD
# 2            109       EDNA       WEST             7       EDNA       WEST
# 3            269  CASSANDRA    WALTERS             6  CASSANDRA    WALTERS
# 4            239     MINNIE     ROMERO             6     MINNIE     ROMERO
# ..           ...        ...        ...           ...        ...        ...
# 507          234    CLAUDIA     FULLER             1    CLAUDIA     FULLER
# 508          431       JOEL  FRANCISCO             1       JOEL  FRANCISCO
# 509          351       JACK      FOUST             1       JACK      FOUST
# 510           10    DOROTHY     TAYLOR             1    DOROTHY     TAYLOR
# 511          136      ANITA    MORALES             1      ANITA    MORALES
#
#      num_rentas_y  diff
# 0               8     0
# ...

# %% [markdown]
#  # <font color='darkcyan'># Forma 3 </font>

# %%
data3=data1.merge(data2, left_on='customer_id', right_on='customer_id') 
def check_rents3(df):
    condiciones = [ df['num_rentas_y'] - df['num_rentas_x']>0, data3['num_rentas_y'] - df['num_rentas_x']<0, df['num_rentas_y'] - df['num_rentas_x']==0  ]
    opciones = ['Rentaron mas en Junio','Rentaron mas en Mayo', 'Rentaron lo mismo']
    df['diff2']=np.select(condiciones,opciones)
    return df

# %%
check_rents3(data3)
# Out:
#      customer_id   nombre_x apellido_x  num_rentas_x   nombre_y apellido_y  \
# 0            197        SUE     PETERS             8        SUE     PETERS
# 1            506     LESLIE     SEWARD             7     LESLIE     SEWARD
# 2            109       EDNA       WEST             7       EDNA       WEST
# 3            269  CASSANDRA    WALTERS             6  CASSANDRA    WALTERS
# 4            239     MINNIE     ROMERO             6     MINNIE     ROMERO
# ..           ...        ...        ...           ...        ...        ...
# 507          234    CLAUDIA     FULLER             1    CLAUDIA     FULLER
# 508          431       JOEL  FRANCISCO             1       JOEL  FRANCISCO
# 509          351       JACK      FOUST             1       JACK      FOUST
# 510           10    DOROTHY     TAYLOR             1    DOROTHY     TAYLOR
# 511          136      ANITA    MORALES             1      ANITA    MORALES
#
#      num_rentas_y                  diff2
# ...
